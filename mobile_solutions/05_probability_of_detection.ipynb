# %% [markdown]
# # Generate Probability of Detection for Operators
#
# Code author: Audrey McManemin
#
# Modified from code written by Sahar H. El Abbadi.
#
# Date started: 2024-09-13
# Date last edited: 2024-09-13
#
# This notebook generates individual probability of detection plots for each operator. Number of bins and the maximum value ("threshold") for the probability of detection plot can be adjusted in each cell.

# %%
# Imports
from plot_methods import plot_detection_limit

# %% [markdown]
# ## Aeromon

# %%
operator = 'Aeromon'
n_bins = 5
threshold = 10

plot_detection_limit(operator, n_bins, threshold, save_plot=True)
# Out:
# /Users/audreymcmanemin/Desktop/RESEARCH/TADI_controlled_release_2024_code/mobile_solutions/plot_methods.py:297: RuntimeWarning: invalid value encountered in scalar divide
#   p = binned_data.operator_detected.sum() / binned_data.shape[0];  # df.shape[0] gives number of rows
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %% [markdown]
# ## GSMA

# %%
operator = 'GSMA'
n_bins = 2
threshold = 6

plot_detection_limit(operator, n_bins, threshold, save_plot=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'detected'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       2 n_bins = 2
#       3 threshold = 6
# ...

# %% [markdown]
# ## DTU

# %%
operator = 'DTU'
n_bins = 3
threshold = 5

plot_detection_limit(operator, n_bins, threshold, save_plot=False)

# %% [markdown]
# ## SeekOps

# %%
operator = 'SeekOps'
n_bins = 3
threshold = 3

plot_detection_limit(operator, n_bins, threshold, save_plot=True)
# Out:
# SeekOps detected all non-zero releases.

# %% [markdown]
# ## Heidelberg University

# %%
operator = 'UHEI'
n_bins = 3
threshold = 3

plot_detection_limit(operator, n_bins, threshold, save_plot=True)
# Out:
# /Users/audreymcmanemin/Desktop/RESEARCH/TADI_controlled_release_2024_code/drones/plot_methods.py:296: RuntimeWarning: invalid value encountered in long_scalars
#   p = binned_data.detected.sum() / binned_data.shape[0];  # df.shape[0] gives number of rows
# UHEI detected all non-zero releases.

# %% [markdown]
# ## Flylogix

# %%
operator = 'Flylogix'
n_bins = 2
threshold = 10

plot_detection_limit(operator, n_bins, threshold, save_plot=True)

# %% [markdown]
# ## EMPA

# %%
operator = 'EMPA'
n_bins = 6
threshold = 30

plot_detection_limit(operator, n_bins, threshold, save_plot=False)
# Out:
# /Users/audreymcmanemin/Desktop/RESEARCH/TADI_controlled_release_2024_code/mobile solutions/plot_methods.py:297: RuntimeWarning: invalid value encountered in scalar divide
#   p = binned_data.detected.sum() / binned_data.shape[0];  # df.shape[0] gives number of rows

# %% [markdown]
# ## UU/LSCE/CYI/RHUL

# %%
operator = 'UU_LSCE_CYI_RHUL'
n_bins = 3
threshold = 6

plot_detection_limit(operator, n_bins, threshold, save_plot=False)
